# %%
import os
import numpy as np
import yaml 
import matplotlib.pyplot as plt
import seaborn as sns
path = '/Users/liuzhishuai/Desktop/new code/code-0102-1/analysis/results/lattice/0'
lis = os.listdir(path)
FILE = []
for i in range(len(lis)):
    FILE.append(os.path.join(path, lis[i]))

def read_data(FILE_path):
    infer_cfg = open(FILE_path)
    data = infer_cfg.read()
    yaml_reader = yaml.load(data, Loader=yaml.FullLoader)
    data_value = []
    data_score = []
    for j in range(20):
        data_value.append(yaml_reader['results'][j]['V'])
        data_score.append(yaml_reader['results'][j]['score'])
    return data_value, data_score
policy = []
Data_value = []
Data_score = []
for i in range(len(FILE)):
    if 'one_step' in FILE[i]:
        if 'learn-embedding=True' in FILE[i]:
            policy = np.hstack((policy,['M-g' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        elif 'raw-feature=True' in FILE[i]:
            policy = np.hstack((policy,['M-r' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        else:
            policy = np.hstack((policy,['M-h' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
    elif 'two_step' in FILE[i]:
        if 'learn-embedding=True' in FILE[i]:
            policy = np.hstack((policy,['F-g-2' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        elif 'raw-feature=True' in FILE[i]:
            policy = np.hstack((policy,['F-r-2' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        else:
            policy = np.hstack((policy,['F-h-2' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
    elif 'three_step' in FILE[i]:
        if 'learn-embedding=True' in FILE[i]:
            policy = np.hstack((policy,['F-g-3' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        elif 'raw-feature=True' in FILE[i]:
            policy = np.hstack((policy,['F-r-3' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        else:
            policy = np.hstack((policy,['F-h-3' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
    elif 'oracle_policy_search' in FILE[i]:
        policy = np.hstack((policy,['OPS' for i in range(20)]))
        temp1, temp2 = read_data(FILE[i])
        Data_value.append(temp1)
        Data_score.append(temp2)
    elif 'policy_search' in FILE[i]:
        policy = np.hstack((policy,['PS' for i in range(20)]))
        temp1, temp2 = read_data(FILE[i])
        Data_value.append(temp1)
        Data_score.append(temp2)
    elif 'true_probs' in FILE[i]:
        policy = np.hstack((policy,['TP' for i in range(20)]))
        temp1, temp2 = read_data(FILE[i])
        Data_value.append(temp1)
        Data_score.append(temp2)
    elif '.DS_Store' in FILE[i]:
        continue
    else:
        policy = np.hstack((policy,['Rand' for i in range(20)]))
        temp1, temp2 = read_data(FILE[i])
        Data_value.append(temp1)
        Data_score.append(temp2)
data = {}
data['value'] = np.hstack(Data_value)
data['score'] = np.hstack(Data_score)
data['policy'] = policy

plt.figure(dpi=100)
g = sns.boxplot(x = data['policy'], y = data['score'],
           showmeans = True, meanline = True, 
           #order = ['F-raw', 'F-hc', 'F-gnn', 'M-raw', 'M-hc', 'M-gnn', 'PS', 'random', 'OPS', 'TP'], 
           #order = ['F-raw-3', 'F-hc-3', 'F-gnn-3', 'F-raw-2', 'F-hc-2', 'F-gnn-2', 'M-raw', 'M-hc', 'M-gnn', 'random', 'PS', 'OPS', 'TP'],
           order = ['F-r-3', 'F-h-3', 'F-g-3', 'F-r-2', 'F-h-2', 'F-g-2', 'M-r', 'M-h', 'M-g', 'Rand', 'PS', 'OPS', 'TP'],
           meanprops={'color':'black'}, fliersize = 0)
g.set(xlabel = r'$\epsilon$=0')
plt.show()

# %%
import os
import numpy as np
import yaml 
import matplotlib.pyplot as plt
import seaborn as sns
path = '/Users/liuzhishuai/Desktop/new code/code-0102-1/analysis/results/lattice/0.5'
lis = os.listdir(path)
FILE = []
for i in range(len(lis)):
    FILE.append(os.path.join(path, lis[i]))

def read_data(FILE_path):
    infer_cfg = open(FILE_path)
    data = infer_cfg.read()
    yaml_reader = yaml.load(data, Loader=yaml.FullLoader)
    data_value = []
    data_score = []
    for j in range(20):
        data_value.append(yaml_reader['results'][j]['V'])
        data_score.append(yaml_reader['results'][j]['score'])
    return data_value, data_score
policy = []
Data_value = []
Data_score = []
for i in range(len(FILE)):
    if 'one_step' in FILE[i]:
        if 'learn-embedding=True' in FILE[i]:
            policy = np.hstack((policy,['M-g' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        elif 'raw-feature=True' in FILE[i]:
            policy = np.hstack((policy,['M-r' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        else:
            policy = np.hstack((policy,['M-h' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
    elif 'two_step' in FILE[i]:
        if 'learn-embedding=True' in FILE[i]:
            policy = np.hstack((policy,['F-g-2' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        elif 'raw-feature=True' in FILE[i]:
            policy = np.hstack((policy,['F-r-2' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        else:
            policy = np.hstack((policy,['F-h-2' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
    elif 'three_step' in FILE[i]:
        if 'learn-embedding=True' in FILE[i]:
            policy = np.hstack((policy,['F-g-3' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        elif 'raw-feature=True' in FILE[i]:
            policy = np.hstack((policy,['F-r-3' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        else:
            policy = np.hstack((policy,['F-h-3' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
    elif 'oracle_policy_search' in FILE[i]:
        policy = np.hstack((policy,['OPS' for i in range(20)]))
        temp1, temp2 = read_data(FILE[i])
        Data_value.append(temp1)
        Data_score.append(temp2)
    elif 'policy_search' in FILE[i]:
        policy = np.hstack((policy,['PS' for i in range(20)]))
        temp1, temp2 = read_data(FILE[i])
        Data_value.append(temp1)
        Data_score.append(temp2)
    elif 'true_probs' in FILE[i]:
        policy = np.hstack((policy,['TP' for i in range(20)]))
        temp1, temp2 = read_data(FILE[i])
        Data_value.append(temp1)
        Data_score.append(temp2)
    elif '.DS_Store' in FILE[i]:
        continue
    else:
        policy = np.hstack((policy,['Rand' for i in range(20)]))
        temp1, temp2 = read_data(FILE[i])
        Data_value.append(temp1)
        Data_score.append(temp2)
data = {}
data['value'] = np.hstack(Data_value)
data['score'] = np.hstack(Data_score)
data['policy'] = policy

plt.figure(dpi=100)
g = sns.boxplot(x = data['policy'], y = data['score'],
           showmeans = True, meanline = True, 
           #order = ['F-raw', 'F-hc', 'F-gnn', 'M-raw', 'M-hc', 'M-gnn', 'PS', 'random', 'OPS', 'TP'], 
           #order = ['F-raw-3', 'F-hc-3', 'F-gnn-3', 'F-raw-2', 'F-hc-2', 'F-gnn-2', 'M-raw', 'M-hc', 'M-gnn', 'random', 'PS', 'OPS', 'TP'],
           order = ['F-r-3', 'F-h-3', 'F-g-3', 'F-r-2', 'F-h-2', 'F-g-2', 'M-r', 'M-h', 'M-g', 'Rand', 'PS', 'OPS', 'TP'],
           meanprops={'color':'black'}, fliersize = 0)
g.set(xlabel = r'$\epsilon$=0.5')
plt.show()

# %%
import os
import numpy as np
import yaml 
import matplotlib.pyplot as plt
import seaborn as sns
path = '/Users/liuzhishuai/Desktop/new code/code-0102-1/analysis/results/lattice/1'
lis = os.listdir(path)
FILE = []
for i in range(len(lis)):
    FILE.append(os.path.join(path, lis[i]))

def read_data(FILE_path):
    infer_cfg = open(FILE_path)
    data = infer_cfg.read()
    yaml_reader = yaml.load(data, Loader=yaml.FullLoader)
    data_value = []
    data_score = []
    for j in range(20):
        data_value.append(yaml_reader['results'][j]['V'])
        data_score.append(yaml_reader['results'][j]['score'])
    return data_value, data_score
policy = []
Data_value = []
Data_score = []
for i in range(len(FILE)):
    if 'one_step' in FILE[i]:
        if 'learn-embedding=True' in FILE[i]:
            policy = np.hstack((policy,['M-g' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        elif 'raw-feature=True' in FILE[i]:
            policy = np.hstack((policy,['M-r' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        else:
            policy = np.hstack((policy,['M-h' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
    elif 'two_step' in FILE[i]:
        if 'learn-embedding=True' in FILE[i]:
            policy = np.hstack((policy,['F-g-2' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        elif 'raw-feature=True' in FILE[i]:
            policy = np.hstack((policy,['F-r-2' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        else:
            policy = np.hstack((policy,['F-h-2' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
    elif 'three_step' in FILE[i]:
        if 'learn-embedding=True' in FILE[i]:
            policy = np.hstack((policy,['F-g-3' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        elif 'raw-feature=True' in FILE[i]:
            policy = np.hstack((policy,['F-r-3' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        else:
            policy = np.hstack((policy,['F-h-3' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
    elif 'oracle_policy_search' in FILE[i]:
        policy = np.hstack((policy,['OPS' for i in range(20)]))
        temp1, temp2 = read_data(FILE[i])
        Data_value.append(temp1)
        Data_score.append(temp2)
    elif 'policy_search' in FILE[i]:
        policy = np.hstack((policy,['PS' for i in range(20)]))
        temp1, temp2 = read_data(FILE[i])
        Data_value.append(temp1)
        Data_score.append(temp2)
    elif 'true_probs' in FILE[i]:
        policy = np.hstack((policy,['TP' for i in range(20)]))
        temp1, temp2 = read_data(FILE[i])
        Data_value.append(temp1)
        Data_score.append(temp2)
    elif '.DS_Store' in FILE[i]:
        continue
    else:
        policy = np.hstack((policy,['Rand' for i in range(20)]))
        temp1, temp2 = read_data(FILE[i])
        Data_value.append(temp1)
        Data_score.append(temp2)
data = {}
data['value'] = np.hstack(Data_value)
data['score'] = np.hstack(Data_score)
data['policy'] = policy

plt.figure(dpi=100)
g = sns.boxplot(x = data['policy'], y = data['score'],
           showmeans = True, meanline = True, 
           #order = ['F-raw', 'F-hc', 'F-gnn', 'M-raw', 'M-hc', 'M-gnn', 'PS', 'random', 'OPS', 'TP'], 
           #order = ['F-raw-3', 'F-hc-3', 'F-gnn-3', 'F-raw-2', 'F-hc-2', 'F-gnn-2', 'M-raw', 'M-hc', 'M-gnn', 'random', 'PS', 'OPS', 'TP'],
           order = ['F-r-3', 'F-h-3', 'F-g-3', 'F-r-2', 'F-h-2', 'F-g-2', 'M-r', 'M-h', 'M-g', 'Rand', 'PS', 'OPS', 'TP'],
           meanprops={'color':'black'}, fliersize = 0)
g.set(xlabel = r'$\epsilon$=1')
plt.show()

# %%
import os
import numpy as np
import yaml 
import matplotlib.pyplot as plt
import seaborn as sns
path = '/Users/liuzhishuai/Desktop/new code/code-0102-1/analysis/results/nn/0'
lis = os.listdir(path)
FILE = []
for i in range(len(lis)):
    FILE.append(os.path.join(path, lis[i]))

def read_data(FILE_path):
    infer_cfg = open(FILE_path)
    data = infer_cfg.read()
    yaml_reader = yaml.load(data, Loader=yaml.FullLoader)
    data_value = []
    data_score = []
    for j in range(20):
        data_value.append(yaml_reader['results'][j]['V'])
        data_score.append(yaml_reader['results'][j]['score'])
    return data_value, data_score
policy = []
Data_value = []
Data_score = []
for i in range(len(FILE)):
    if 'one_step' in FILE[i]:
        if 'learn-embedding=True' in FILE[i]:
            policy = np.hstack((policy,['M-g' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        elif 'raw-feature=True' in FILE[i]:
            policy = np.hstack((policy,['M-r' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        else:
            policy = np.hstack((policy,['M-h' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
    elif 'two_step' in FILE[i]:
        if 'learn-embedding=True' in FILE[i]:
            policy = np.hstack((policy,['F-g-2' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        elif 'raw-feature=True' in FILE[i]:
            policy = np.hstack((policy,['F-r-2' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        else:
            policy = np.hstack((policy,['F-h-2' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
    elif 'three_step' in FILE[i]:
        if 'learn-embedding=True' in FILE[i]:
            policy = np.hstack((policy,['F-g-3' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        elif 'raw-feature=True' in FILE[i]:
            policy = np.hstack((policy,['F-r-3' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        else:
            policy = np.hstack((policy,['F-h-3' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
    elif 'oracle_policy_search' in FILE[i]:
        policy = np.hstack((policy,['OPS' for i in range(20)]))
        temp1, temp2 = read_data(FILE[i])
        Data_value.append(temp1)
        Data_score.append(temp2)
    elif 'policy_search' in FILE[i]:
        policy = np.hstack((policy,['PS' for i in range(20)]))
        temp1, temp2 = read_data(FILE[i])
        Data_value.append(temp1)
        Data_score.append(temp2)
    elif 'true_probs' in FILE[i]:
        policy = np.hstack((policy,['TP' for i in range(20)]))
        temp1, temp2 = read_data(FILE[i])
        Data_value.append(temp1)
        Data_score.append(temp2)
    elif '.DS_Store' in FILE[i]:
        continue
    else:
        policy = np.hstack((policy,['Rand' for i in range(20)]))
        temp1, temp2 = read_data(FILE[i])
        Data_value.append(temp1)
        Data_score.append(temp2)
data = {}
data['value'] = np.hstack(Data_value)
data['score'] = np.hstack(Data_score)
data['policy'] = policy

plt.figure(dpi=100)
g = sns.boxplot(x = data['policy'], y = data['score'],
           showmeans = True, meanline = True, 
           #order = ['F-raw', 'F-hc', 'F-gnn', 'M-raw', 'M-hc', 'M-gnn', 'PS', 'random', 'OPS', 'TP'], 
           #order = ['F-raw-3', 'F-hc-3', 'F-gnn-3', 'F-raw-2', 'F-hc-2', 'F-gnn-2', 'M-raw', 'M-hc', 'M-gnn', 'random', 'PS', 'OPS', 'TP'],
           order = ['F-r-3', 'F-h-3', 'F-g-3', 'F-r-2', 'F-h-2', 'F-g-2', 'M-r', 'M-h', 'M-g', 'Rand', 'PS', 'OPS', 'TP'],
           meanprops={'color':'black'}, fliersize = 0)
g.set(xlabel = r'$\epsilon$=0')
plt.show()

# %%
import os
import numpy as np
import yaml 
import matplotlib.pyplot as plt
import seaborn as sns
path = '/Users/liuzhishuai/Desktop/new code/code-0102-1/analysis/results/nn/0.5'
lis = os.listdir(path)
FILE = []
for i in range(len(lis)):
    FILE.append(os.path.join(path, lis[i]))

def read_data(FILE_path):
    infer_cfg = open(FILE_path)
    data = infer_cfg.read()
    yaml_reader = yaml.load(data, Loader=yaml.FullLoader)
    data_value = []
    data_score = []
    for j in range(20):
        data_value.append(yaml_reader['results'][j]['V'])
        data_score.append(yaml_reader['results'][j]['score'])
    return data_value, data_score
policy = []
Data_value = []
Data_score = []
for i in range(len(FILE)):
    if 'one_step' in FILE[i]:
        if 'learn-embedding=True' in FILE[i]:
            policy = np.hstack((policy,['M-g' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        elif 'raw-feature=True' in FILE[i]:
            policy = np.hstack((policy,['M-r' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        else:
            policy = np.hstack((policy,['M-h' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
    elif 'two_step' in FILE[i]:
        if 'learn-embedding=True' in FILE[i]:
            policy = np.hstack((policy,['F-g-2' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        elif 'raw-feature=True' in FILE[i]:
            policy = np.hstack((policy,['F-r-2' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        else:
            policy = np.hstack((policy,['F-h-2' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
    elif 'three_step' in FILE[i]:
        if 'learn-embedding=True' in FILE[i]:
            policy = np.hstack((policy,['F-g-3' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        elif 'raw-feature=True' in FILE[i]:
            policy = np.hstack((policy,['F-r-3' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        else:
            policy = np.hstack((policy,['F-h-3' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
    elif 'oracle_policy_search' in FILE[i]:
        policy = np.hstack((policy,['OPS' for i in range(20)]))
        temp1, temp2 = read_data(FILE[i])
        Data_value.append(temp1)
        Data_score.append(temp2)
    elif 'policy_search' in FILE[i]:
        policy = np.hstack((policy,['PS' for i in range(20)]))
        temp1, temp2 = read_data(FILE[i])
        Data_value.append(temp1)
        Data_score.append(temp2)
    elif 'true_probs' in FILE[i]:
        policy = np.hstack((policy,['TP' for i in range(20)]))
        temp1, temp2 = read_data(FILE[i])
        Data_value.append(temp1)
        Data_score.append(temp2)
    elif '.DS_Store' in FILE[i]:
        continue
    else:
        policy = np.hstack((policy,['Rand' for i in range(20)]))
        temp1, temp2 = read_data(FILE[i])
        Data_value.append(temp1)
        Data_score.append(temp2)
data = {}
data['value'] = np.hstack(Data_value)
data['score'] = np.hstack(Data_score)
data['policy'] = policy

plt.figure(dpi=100)
g = sns.boxplot(x = data['policy'], y = data['score'],
           showmeans = True, meanline = True, 
           #order = ['F-raw', 'F-hc', 'F-gnn', 'M-raw', 'M-hc', 'M-gnn', 'PS', 'random', 'OPS', 'TP'], 
           #order = ['F-raw-3', 'F-hc-3', 'F-gnn-3', 'F-raw-2', 'F-hc-2', 'F-gnn-2', 'M-raw', 'M-hc', 'M-gnn', 'random', 'PS', 'OPS', 'TP'],
           order = ['F-r-3', 'F-h-3', 'F-g-3', 'F-r-2', 'F-h-2', 'F-g-2', 'M-r', 'M-h', 'M-g', 'Rand', 'PS', 'OPS', 'TP'],
           meanprops={'color':'black'}, fliersize = 0)
g.set(xlabel = r'$\epsilon$=0.5')
plt.show()

# %%
import os
import numpy as np
import yaml 
import matplotlib.pyplot as plt
import seaborn as sns
path = '/Users/liuzhishuai/Desktop/new code/code-0102-1/analysis/results/nn/1'
lis = os.listdir(path)
FILE = []
for i in range(len(lis)):
    FILE.append(os.path.join(path, lis[i]))

def read_data(FILE_path):
    infer_cfg = open(FILE_path)
    data = infer_cfg.read()
    yaml_reader = yaml.load(data, Loader=yaml.FullLoader)
    data_value = []
    data_score = []
    for j in range(20):
        data_value.append(yaml_reader['results'][j]['V'])
        data_score.append(yaml_reader['results'][j]['score'])
    return data_value, data_score
policy = []
Data_value = []
Data_score = []
for i in range(len(FILE)):
    if 'one_step' in FILE[i]:
        if 'learn-embedding=True' in FILE[i]:
            policy = np.hstack((policy,['M-g' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        elif 'raw-feature=True' in FILE[i]:
            policy = np.hstack((policy,['M-r' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        else:
            policy = np.hstack((policy,['M-h' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
    elif 'two_step' in FILE[i]:
        if 'learn-embedding=True' in FILE[i]:
            policy = np.hstack((policy,['F-g-2' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        elif 'raw-feature=True' in FILE[i]:
            policy = np.hstack((policy,['F-r-2' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        else:
            policy = np.hstack((policy,['F-h-2' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
    elif 'three_step' in FILE[i]:
        if 'learn-embedding=True' in FILE[i]:
            policy = np.hstack((policy,['F-g-3' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        elif 'raw-feature=True' in FILE[i]:
            policy = np.hstack((policy,['F-r-3' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        else:
            policy = np.hstack((policy,['F-h-3' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
    elif 'oracle_policy_search' in FILE[i]:
        policy = np.hstack((policy,['OPS' for i in range(20)]))
        temp1, temp2 = read_data(FILE[i])
        Data_value.append(temp1)
        Data_score.append(temp2)
    elif 'policy_search' in FILE[i]:
        policy = np.hstack((policy,['PS' for i in range(20)]))
        temp1, temp2 = read_data(FILE[i])
        Data_value.append(temp1)
        Data_score.append(temp2)
    elif 'true_probs' in FILE[i]:
        policy = np.hstack((policy,['TP' for i in range(20)]))
        temp1, temp2 = read_data(FILE[i])
        Data_value.append(temp1)
        Data_score.append(temp2)
    elif '.DS_Store' in FILE[i]:
        continue
    else:
        policy = np.hstack((policy,['Rand' for i in range(20)]))
        temp1, temp2 = read_data(FILE[i])
        Data_value.append(temp1)
        Data_score.append(temp2)
data = {}
data['value'] = np.hstack(Data_value)
data['score'] = np.hstack(Data_score)
data['policy'] = policy

plt.figure(dpi=100)
g = sns.boxplot(x = data['policy'], y = data['score'],
           showmeans = True, meanline = True, 
           #order = ['F-raw', 'F-hc', 'F-gnn', 'M-raw', 'M-hc', 'M-gnn', 'PS', 'random', 'OPS', 'TP'], 
           #order = ['F-raw-3', 'F-hc-3', 'F-gnn-3', 'F-raw-2', 'F-hc-2', 'F-gnn-2', 'M-raw', 'M-hc', 'M-gnn', 'random', 'PS', 'OPS', 'TP'],
           order = ['F-r-3', 'F-h-3', 'F-g-3', 'F-r-2', 'F-h-2', 'F-g-2', 'M-r', 'M-h', 'M-g', 'Rand', 'PS', 'OPS', 'TP'],
           meanprops={'color':'black'}, fliersize = 0)
g.set(xlabel = r'$\epsilon$=1')
plt.show()

# %%
import os
import numpy as np
import yaml 
import matplotlib.pyplot as plt
import seaborn as sns
path = '/Users/liuzhishuai/Desktop/new code/code-0102-1/analysis/results/contrived/0'
lis = os.listdir(path)
FILE = []
for i in range(len(lis)):
    FILE.append(os.path.join(path, lis[i]))

def read_data(FILE_path):
    infer_cfg = open(FILE_path)
    data = infer_cfg.read()
    yaml_reader = yaml.load(data, Loader=yaml.FullLoader)
    data_value = []
    data_score = []
    for j in range(20):
        data_value.append(yaml_reader['results'][j]['V'])
        data_score.append(yaml_reader['results'][j]['score'])
    return data_value, data_score
policy = []
Data_value = []
Data_score = []
for i in range(len(FILE)):
    if 'one_step' in FILE[i]:
        if 'learn-embedding=True' in FILE[i]:
            policy = np.hstack((policy,['M-g' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        elif 'raw-feature=True' in FILE[i]:
            policy = np.hstack((policy,['M-r' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        else:
            policy = np.hstack((policy,['M-h' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
    elif 'two_step' in FILE[i]:
        if 'learn-embedding=True' in FILE[i]:
            policy = np.hstack((policy,['F-g-2' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        elif 'raw-feature=True' in FILE[i]:
            policy = np.hstack((policy,['F-r-2' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        else:
            policy = np.hstack((policy,['F-h-2' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
    elif 'three_step' in FILE[i]:
        if 'learn-embedding=True' in FILE[i]:
            policy = np.hstack((policy,['F-g-3' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        elif 'raw-feature=True' in FILE[i]:
            policy = np.hstack((policy,['F-r-3' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        else:
            policy = np.hstack((policy,['F-h-3' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
    elif 'oracle_policy_search' in FILE[i]:
        policy = np.hstack((policy,['OPS' for i in range(20)]))
        temp1, temp2 = read_data(FILE[i])
        Data_value.append(temp1)
        Data_score.append(temp2)
    elif 'policy_search' in FILE[i]:
        policy = np.hstack((policy,['PS' for i in range(20)]))
        temp1, temp2 = read_data(FILE[i])
        Data_value.append(temp1)
        Data_score.append(temp2)
    elif 'true_probs' in FILE[i]:
        policy = np.hstack((policy,['TP' for i in range(20)]))
        temp1, temp2 = read_data(FILE[i])
        Data_value.append(temp1)
        Data_score.append(temp2)
    elif '.DS_Store' in FILE[i]:
        continue
    else:
        policy = np.hstack((policy,['Rand' for i in range(20)]))
        temp1, temp2 = read_data(FILE[i])
        Data_value.append(temp1)
        Data_score.append(temp2)
data = {}
data['value'] = np.hstack(Data_value)
data['score'] = np.hstack(Data_score)
data['policy'] = policy

plt.figure(dpi=100)
g = sns.boxplot(x = data['policy'], y = data['score'],
           showmeans = True, meanline = True, 
           #order = ['F-raw', 'F-hc', 'F-gnn', 'M-raw', 'M-hc', 'M-gnn', 'PS', 'random', 'OPS', 'TP'], 
           #order = ['F-raw-3', 'F-hc-3', 'F-gnn-3', 'F-raw-2', 'F-hc-2', 'F-gnn-2', 'M-raw', 'M-hc', 'M-gnn', 'random', 'PS', 'OPS', 'TP'],
           order = ['F-r-3', 'F-h-3', 'F-g-3', 'F-r-2', 'F-h-2', 'F-g-2', 'M-r', 'M-h', 'M-g', 'Rand', 'PS', 'OPS', 'TP'],
           meanprops={'color':'black'}, fliersize = 0)
g.set(xlabel = r'$\epsilon$=0')
plt.show()

# %%
import os
import numpy as np
import yaml 
import matplotlib.pyplot as plt
import seaborn as sns
path = '/Users/liuzhishuai/Desktop/new code/code-0102-1/analysis/results/contrived/0.5'
lis = os.listdir(path)
FILE = []
for i in range(len(lis)):
    FILE.append(os.path.join(path, lis[i]))

def read_data(FILE_path):
    infer_cfg = open(FILE_path)
    data = infer_cfg.read()
    yaml_reader = yaml.load(data, Loader=yaml.FullLoader)
    data_value = []
    data_score = []
    for j in range(20):
        data_value.append(yaml_reader['results'][j]['V'])
        data_score.append(yaml_reader['results'][j]['score'])
    return data_value, data_score
policy = []
Data_value = []
Data_score = []
for i in range(len(FILE)):
    if 'one_step' in FILE[i]:
        if 'learn-embedding=True' in FILE[i]:
            policy = np.hstack((policy,['M-g' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        elif 'raw-feature=True' in FILE[i]:
            policy = np.hstack((policy,['M-r' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        else:
            policy = np.hstack((policy,['M-h' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
    elif 'two_step' in FILE[i]:
        if 'learn-embedding=True' in FILE[i]:
            policy = np.hstack((policy,['F-g-2' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        elif 'raw-feature=True' in FILE[i]:
            policy = np.hstack((policy,['F-r-2' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        else:
            policy = np.hstack((policy,['F-h-2' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
    elif 'three_step' in FILE[i]:
        if 'learn-embedding=True' in FILE[i]:
            policy = np.hstack((policy,['F-g-3' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        elif 'raw-feature=True' in FILE[i]:
            policy = np.hstack((policy,['F-r-3' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        else:
            policy = np.hstack((policy,['F-h-3' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
    elif 'oracle_policy_search' in FILE[i]:
        policy = np.hstack((policy,['OPS' for i in range(20)]))
        temp1, temp2 = read_data(FILE[i])
        Data_value.append(temp1)
        Data_score.append(temp2)
    elif 'policy_search' in FILE[i]:
        policy = np.hstack((policy,['PS' for i in range(20)]))
        temp1, temp2 = read_data(FILE[i])
        Data_value.append(temp1)
        Data_score.append(temp2)
    elif 'true_probs' in FILE[i]:
        policy = np.hstack((policy,['TP' for i in range(20)]))
        temp1, temp2 = read_data(FILE[i])
        Data_value.append(temp1)
        Data_score.append(temp2)
    elif '.DS_Store' in FILE[i]:
        continue
    else:
        policy = np.hstack((policy,['Rand' for i in range(20)]))
        temp1, temp2 = read_data(FILE[i])
        Data_value.append(temp1)
        Data_score.append(temp2)
data = {}
data['value'] = np.hstack(Data_value)
data['score'] = np.hstack(Data_score)
data['policy'] = policy

plt.figure(dpi=100)
g = sns.boxplot(x = data['policy'], y = data['score'],
           showmeans = True, meanline = True, 
           #order = ['F-raw', 'F-hc', 'F-gnn', 'M-raw', 'M-hc', 'M-gnn', 'PS', 'random', 'OPS', 'TP'], 
           #order = ['F-raw-3', 'F-hc-3', 'F-gnn-3', 'F-raw-2', 'F-hc-2', 'F-gnn-2', 'M-raw', 'M-hc', 'M-gnn', 'random', 'PS', 'OPS', 'TP'],
           order = ['F-r-3', 'F-h-3', 'F-g-3', 'F-r-2', 'F-h-2', 'F-g-2', 'M-r', 'M-h', 'M-g', 'Rand', 'PS', 'OPS', 'TP'],
           meanprops={'color':'black'}, fliersize = 0)
g.set(xlabel = r'$\epsilon$=0.5')
plt.show()

# %%
import os
import numpy as np
import yaml 
import matplotlib.pyplot as plt
import seaborn as sns
path = '/Users/liuzhishuai/Desktop/new code/code-0102-1/analysis/results/contrived/1'
lis = os.listdir(path)
FILE = []
for i in range(len(lis)):
    FILE.append(os.path.join(path, lis[i]))

def read_data(FILE_path):
    infer_cfg = open(FILE_path)
    data = infer_cfg.read()
    yaml_reader = yaml.load(data, Loader=yaml.FullLoader)
    data_value = []
    data_score = []
    for j in range(20):
        data_value.append(yaml_reader['results'][j]['V'])
        data_score.append(yaml_reader['results'][j]['score'])
    return data_value, data_score
policy = []
Data_value = []
Data_score = []
for i in range(len(FILE)):
    if 'one_step' in FILE[i]:
        if 'learn-embedding=True' in FILE[i]:
            policy = np.hstack((policy,['M-g' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        elif 'raw-feature=True' in FILE[i]:
            policy = np.hstack((policy,['M-r' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        else:
            policy = np.hstack((policy,['M-h' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
    elif 'two_step' in FILE[i]:
        if 'learn-embedding=True' in FILE[i]:
            policy = np.hstack((policy,['F-g-2' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        elif 'raw-feature=True' in FILE[i]:
            policy = np.hstack((policy,['F-r-2' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        else:
            policy = np.hstack((policy,['F-h-2' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
    elif 'three_step' in FILE[i]:
        if 'learn-embedding=True' in FILE[i]:
            policy = np.hstack((policy,['F-g-3' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        elif 'raw-feature=True' in FILE[i]:
            policy = np.hstack((policy,['F-r-3' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        else:
            policy = np.hstack((policy,['F-h-3' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
    elif 'oracle_policy_search' in FILE[i]:
        policy = np.hstack((policy,['OPS' for i in range(20)]))
        temp1, temp2 = read_data(FILE[i])
        Data_value.append(temp1)
        Data_score.append(temp2)
    elif 'policy_search' in FILE[i]:
        policy = np.hstack((policy,['PS' for i in range(20)]))
        temp1, temp2 = read_data(FILE[i])
        Data_value.append(temp1)
        Data_score.append(temp2)
    elif 'true_probs' in FILE[i]:
        policy = np.hstack((policy,['TP' for i in range(20)]))
        temp1, temp2 = read_data(FILE[i])
        Data_value.append(temp1)
        Data_score.append(temp2)
    elif '.DS_Store' in FILE[i]:
        continue
    else:
        policy = np.hstack((policy,['Rand' for i in range(20)]))
        temp1, temp2 = read_data(FILE[i])
        Data_value.append(temp1)
        Data_score.append(temp2)
data = {}
data['value'] = np.hstack(Data_value)
data['score'] = np.hstack(Data_score)
data['policy'] = policy

plt.figure(dpi=100)
g = sns.boxplot(x = data['policy'], y = data['score'],
           showmeans = True, meanline = True, 
           #order = ['F-raw', 'F-hc', 'F-gnn', 'M-raw', 'M-hc', 'M-gnn', 'PS', 'random', 'OPS', 'TP'], 
           #order = ['F-raw-3', 'F-hc-3', 'F-gnn-3', 'F-raw-2', 'F-hc-2', 'F-gnn-2', 'M-raw', 'M-hc', 'M-gnn', 'random', 'PS', 'OPS', 'TP'],
           order = ['F-r-3', 'F-h-3', 'F-g-3', 'F-r-2', 'F-h-2', 'F-g-2', 'M-r', 'M-h', 'M-g', 'Rand', 'PS', 'OPS', 'TP'],
           meanprops={'color':'black'}, fliersize = 0)
g.set(xlabel = r'$\epsilon$=1')
plt.show()
