# %%
import os
import numpy as np
import yaml 
import matplotlib.pyplot as plt
import seaborn as sns
path = '/Users/liuzhishuai/Desktop/results/SIS100-new/lattice/0'
lis = os.listdir(path)
FILE = []
for i in range(len(lis)):
    FILE.append(os.path.join(path, lis[i]))

def read_data(FILE_path):
    infer_cfg = open(FILE_path)
    data = infer_cfg.read()
    yaml_reader = yaml.load(data, Loader=yaml.FullLoader)
    data_value = []
    data_score = []
    for j in range(20):
        data_value.append(yaml_reader['results'][j]['V'])
        data_score.append(yaml_reader['results'][j]['score'])
    return data_value, data_score
policy = []
Data_value = []
Data_score = []
for i in range(len(FILE)):
    if 'one_step' in FILE[i]:
        if 'learn-embedding=True' in FILE[i]:
            policy = np.hstack((policy,['M-gnn' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        elif 'raw-feature=True' in FILE[i]:
            policy = np.hstack((policy,['M-raw' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        else:
            policy = np.hstack((policy,['M-hc' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
    elif 'two_step' in FILE[i]:
        if 'learn-embedding=True' in FILE[i]:
            policy = np.hstack((policy,['F-gnn-2' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        elif 'raw-feature=True' in FILE[i]:
            policy = np.hstack((policy,['F-raw-2' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        else:
            policy = np.hstack((policy,['F-hc-2' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
    elif 'three_step' in FILE[i]:
        if 'learn-embedding=True' in FILE[i]:
            policy = np.hstack((policy,['F-gnn-3' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        elif 'raw-feature=True' in FILE[i]:
            policy = np.hstack((policy,['F-raw-3' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        else:
            policy = np.hstack((policy,['F-hc-3' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
    elif 'oracle_policy_search' in FILE[i]:
        policy = np.hstack((policy,['OPS' for i in range(20)]))
        temp1, temp2 = read_data(FILE[i])
        Data_value.append(temp1)
        Data_score.append(temp2)
    elif 'policy_search' in FILE[i]:
        policy = np.hstack((policy,['PS' for i in range(20)]))
        temp1, temp2 = read_data(FILE[i])
        Data_value.append(temp1)
        Data_score.append(temp2)
    elif 'true_probs' in FILE[i]:
        policy = np.hstack((policy,['TP' for i in range(20)]))
        temp1, temp2 = read_data(FILE[i])
        Data_value.append(temp1)
        Data_score.append(temp2)
    elif '.DS_Store' in FILE[i]:
        continue
    else:
        policy = np.hstack((policy,['random' for i in range(20)]))
        temp1, temp2 = read_data(FILE[i])
        Data_value.append(temp1)
        Data_score.append(temp2)

data = {}
data['value'] = np.hstack(Data_value)
data['score'] = np.hstack(Data_score)
data['policy'] = policy

plt.figure(dpi=100)
g = sns.boxplot(x = data['policy'], y = data['score'],
           showmeans = True, meanline = True, 
           order = ['F-hc-3', 'F-gnn-3', 'M-hc', 'PS', 'random', 'OPS'], 
           meanprops={'color':'black'}, fliersize = 0)
g.set(xlabel = 'correct specified')
g.set(xticklabels=[])
plt.show()

# %%
import os
import numpy as np
import yaml 
import matplotlib.pyplot as plt
import seaborn as sns
path = '/Users/liuzhishuai/Desktop/results/SIS100-new/lattice/0.5'
lis = os.listdir(path)
FILE = []
for i in range(len(lis)):
    FILE.append(os.path.join(path, lis[i]))

def read_data(FILE_path):
    infer_cfg = open(FILE_path)
    data = infer_cfg.read()
    yaml_reader = yaml.load(data, Loader=yaml.FullLoader)
    data_value = []
    data_score = []
    for j in range(20):
        data_value.append(yaml_reader['results'][j]['V'])
        data_score.append(yaml_reader['results'][j]['score'])
    return data_value, data_score
policy = []
Data_value = []
Data_score = []
for i in range(len(FILE)):
    if 'one_step' in FILE[i]:
        if 'learn-embedding=True' in FILE[i]:
            policy = np.hstack((policy,['M-gnn' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        elif 'raw-feature=True' in FILE[i]:
            policy = np.hstack((policy,['M-raw' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        else:
            policy = np.hstack((policy,['M-hc' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
    elif 'two_step' in FILE[i]:
        if 'learn-embedding=True' in FILE[i]:
            policy = np.hstack((policy,['F-gnn-2' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        elif 'raw-feature=True' in FILE[i]:
            policy = np.hstack((policy,['F-raw-2' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        else:
            policy = np.hstack((policy,['F-hc-2' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
    elif 'three_step' in FILE[i]:
        if 'learn-embedding=True' in FILE[i]:
            policy = np.hstack((policy,['F-gnn-3' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        elif 'raw-feature=True' in FILE[i]:
            policy = np.hstack((policy,['F-raw-3' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        else:
            policy = np.hstack((policy,['F-hc-3' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
    elif 'oracle_policy_search' in FILE[i]:
        policy = np.hstack((policy,['OPS' for i in range(20)]))
        temp1, temp2 = read_data(FILE[i])
        Data_value.append(temp1)
        Data_score.append(temp2)
    elif 'policy_search' in FILE[i]:
        policy = np.hstack((policy,['PS' for i in range(20)]))
        temp1, temp2 = read_data(FILE[i])
        Data_value.append(temp1)
        Data_score.append(temp2)
    elif 'true_probs' in FILE[i]:
        policy = np.hstack((policy,['TP' for i in range(20)]))
        temp1, temp2 = read_data(FILE[i])
        Data_value.append(temp1)
        Data_score.append(temp2)
    elif '.DS_Store' in FILE[i]:
        continue
    else:
        policy = np.hstack((policy,['random' for i in range(20)]))
        temp1, temp2 = read_data(FILE[i])
        Data_value.append(temp1)
        Data_score.append(temp2)

data = {}
data['value'] = np.hstack(Data_value)
data['score'] = np.hstack(Data_score)
data['policy'] = policy

plt.figure(dpi=100)
g = sns.boxplot(x = data['policy'], y = data['score'],
           showmeans = True, meanline = True, 
           order = ['F-hc-3', 'F-gnn-3', 'M-hc', 'PS', 'random', 'OPS'], 
           meanprops={'color':'black'}, fliersize = 0)
g.set(xlabel = 'moderate contamination')
g.set(xticklabels=[])
plt.show()

# %%
import os
import numpy as np
import yaml 
import matplotlib.pyplot as plt
import seaborn as sns
path = '/Users/liuzhishuai/Desktop/results/SIS100-new/lattice/1'
lis = os.listdir(path)
FILE = []
for i in range(len(lis)):
    FILE.append(os.path.join(path, lis[i]))

def read_data(FILE_path):
    infer_cfg = open(FILE_path)
    data = infer_cfg.read()
    yaml_reader = yaml.load(data, Loader=yaml.FullLoader)
    data_value = []
    data_score = []
    for j in range(20):
        data_value.append(yaml_reader['results'][j]['V'])
        data_score.append(yaml_reader['results'][j]['score'])
    return data_value, data_score
policy = []
Data_value = []
Data_score = []
for i in range(len(FILE)):
    if 'one_step' in FILE[i]:
        if 'learn-embedding=True' in FILE[i]:
            policy = np.hstack((policy,['M-gnn' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        elif 'raw-feature=True' in FILE[i]:
            policy = np.hstack((policy,['M-raw' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        else:
            policy = np.hstack((policy,['M-hc' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
    elif 'two_step' in FILE[i]:
        if 'learn-embedding=True' in FILE[i]:
            policy = np.hstack((policy,['F-gnn-2' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        elif 'raw-feature=True' in FILE[i]:
            policy = np.hstack((policy,['F-raw-2' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        else:
            policy = np.hstack((policy,['F-hc-2' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
    elif 'three_step' in FILE[i]:
        if 'learn-embedding=True' in FILE[i]:
            policy = np.hstack((policy,['F-gnn-3' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        elif 'raw-feature=True' in FILE[i]:
            policy = np.hstack((policy,['F-raw-3' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        else:
            policy = np.hstack((policy,['F-hc-3' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
    elif 'oracle_policy_search' in FILE[i]:
        policy = np.hstack((policy,['OPS' for i in range(20)]))
        temp1, temp2 = read_data(FILE[i])
        Data_value.append(temp1)
        Data_score.append(temp2)
    elif 'policy_search' in FILE[i]:
        policy = np.hstack((policy,['PS' for i in range(20)]))
        temp1, temp2 = read_data(FILE[i])
        Data_value.append(temp1)
        Data_score.append(temp2)
    elif 'true_probs' in FILE[i]:
        policy = np.hstack((policy,['TP' for i in range(20)]))
        temp1, temp2 = read_data(FILE[i])
        Data_value.append(temp1)
        Data_score.append(temp2)
    elif '.DS_Store' in FILE[i]:
        continue
    else:
        policy = np.hstack((policy,['random' for i in range(20)]))
        temp1, temp2 = read_data(FILE[i])
        Data_value.append(temp1)
        Data_score.append(temp2)

data = {}
data['value'] = np.hstack(Data_value)
data['score'] = np.hstack(Data_score)
data['policy'] = policy

plt.figure(dpi=100)
g = sns.boxplot(x = data['policy'], y = data['score'],
           showmeans = True, meanline = True, 
           order = ['F-hc-3', 'F-gnn-3', 'M-hc', 'PS', 'random', 'OPS'],
           meanprops={'color':'black'}, fliersize = 0)
g.set(xlabel = 'complete contamination')
g.set(xticklabels=[])
plt.show()

# %%
import os
import numpy as np
import yaml 
import matplotlib.pyplot as plt
import seaborn as sns
path = '/Users/liuzhishuai/Desktop/results/SIS100-new/nn/0'
lis = os.listdir(path)
FILE = []
for i in range(len(lis)):
    FILE.append(os.path.join(path, lis[i]))

def read_data(FILE_path):
    infer_cfg = open(FILE_path)
    data = infer_cfg.read()
    yaml_reader = yaml.load(data, Loader=yaml.FullLoader)
    data_value = []
    data_score = []
    for j in range(20):
        data_value.append(yaml_reader['results'][j]['V'])
        data_score.append(yaml_reader['results'][j]['score'])
    return data_value, data_score
policy = []
Data_value = []
Data_score = []
for i in range(len(FILE)):
    if 'one_step' in FILE[i]:
        if 'learn-embedding=True' in FILE[i]:
            policy = np.hstack((policy,['M-gnn' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        elif 'raw-feature=True' in FILE[i]:
            policy = np.hstack((policy,['M-raw' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        else:
            policy = np.hstack((policy,['M-hc' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
    elif 'two_step' in FILE[i]:
        if 'learn-embedding=True' in FILE[i]:
            policy = np.hstack((policy,['F-gnn-2' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        elif 'raw-feature=True' in FILE[i]:
            policy = np.hstack((policy,['F-raw-2' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        else:
            policy = np.hstack((policy,['F-hc-2' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
    elif 'three_step' in FILE[i]:
        if 'learn-embedding=True' in FILE[i]:
            policy = np.hstack((policy,['F-gnn-3' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        elif 'raw-feature=True' in FILE[i]:
            policy = np.hstack((policy,['F-raw-3' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        else:
            policy = np.hstack((policy,['F-hc-3' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
    elif 'oracle_policy_search' in FILE[i]:
        policy = np.hstack((policy,['OPS' for i in range(20)]))
        temp1, temp2 = read_data(FILE[i])
        Data_value.append(temp1)
        Data_score.append(temp2)
    elif 'policy_search' in FILE[i]:
        policy = np.hstack((policy,['PS' for i in range(20)]))
        temp1, temp2 = read_data(FILE[i])
        Data_value.append(temp1)
        Data_score.append(temp2)
    elif 'true_probs' in FILE[i]:
        policy = np.hstack((policy,['TP' for i in range(20)]))
        temp1, temp2 = read_data(FILE[i])
        Data_value.append(temp1)
        Data_score.append(temp2)
    elif '.DS_Store' in FILE[i]:
        continue
    else:
        policy = np.hstack((policy,['random' for i in range(20)]))
        temp1, temp2 = read_data(FILE[i])
        Data_value.append(temp1)
        Data_score.append(temp2)

data = {}
data['value'] = np.hstack(Data_value)
data['score'] = np.hstack(Data_score)
data['policy'] = policy

plt.figure(dpi=100)
g = sns.boxplot(x = data['policy'], y = data['score'],
           showmeans = True, meanline = True, 
           order = ['F-hc-3', 'F-gnn-3', 'M-hc', 'PS', 'random', 'OPS'], 
           meanprops={'color':'black'}, fliersize = 0)
g.set(xlabel = 'correct specified')
g.set(xticklabels=[])
plt.show()

# %%
import os
import numpy as np
import yaml 
import matplotlib.pyplot as plt
import seaborn as sns
path = '/Users/liuzhishuai/Desktop/results/SIS100-new/nn/0.5'
lis = os.listdir(path)
FILE = []
for i in range(len(lis)):
    FILE.append(os.path.join(path, lis[i]))

def read_data(FILE_path):
    infer_cfg = open(FILE_path)
    data = infer_cfg.read()
    yaml_reader = yaml.load(data, Loader=yaml.FullLoader)
    data_value = []
    data_score = []
    for j in range(20):
        data_value.append(yaml_reader['results'][j]['V'])
        data_score.append(yaml_reader['results'][j]['score'])
    return data_value, data_score
policy = []
Data_value = []
Data_score = []
for i in range(len(FILE)):
    if 'one_step' in FILE[i]:
        if 'learn-embedding=True' in FILE[i]:
            policy = np.hstack((policy,['M-gnn' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        elif 'raw-feature=True' in FILE[i]:
            policy = np.hstack((policy,['M-raw' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        else:
            policy = np.hstack((policy,['M-hc' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
    elif 'two_step' in FILE[i]:
        if 'learn-embedding=True' in FILE[i]:
            policy = np.hstack((policy,['F-gnn-2' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        elif 'raw-feature=True' in FILE[i]:
            policy = np.hstack((policy,['F-raw-2' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        else:
            policy = np.hstack((policy,['F-hc-2' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
    elif 'three_step' in FILE[i]:
        if 'learn-embedding=True' in FILE[i]:
            policy = np.hstack((policy,['F-gnn-3' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        elif 'raw-feature=True' in FILE[i]:
            policy = np.hstack((policy,['F-raw-3' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        else:
            policy = np.hstack((policy,['F-hc-3' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
    elif 'oracle_policy_search' in FILE[i]:
        policy = np.hstack((policy,['OPS' for i in range(20)]))
        temp1, temp2 = read_data(FILE[i])
        Data_value.append(temp1)
        Data_score.append(temp2)
    elif 'policy_search' in FILE[i]:
        policy = np.hstack((policy,['PS' for i in range(20)]))
        temp1, temp2 = read_data(FILE[i])
        Data_value.append(temp1)
        Data_score.append(temp2)
    elif 'true_probs' in FILE[i]:
        policy = np.hstack((policy,['TP' for i in range(20)]))
        temp1, temp2 = read_data(FILE[i])
        Data_value.append(temp1)
        Data_score.append(temp2)
    elif '.DS_Store' in FILE[i]:
        continue
    else:
        policy = np.hstack((policy,['random' for i in range(20)]))
        temp1, temp2 = read_data(FILE[i])
        Data_value.append(temp1)
        Data_score.append(temp2)

data = {}
data['value'] = np.hstack(Data_value)
data['score'] = np.hstack(Data_score)
data['policy'] = policy

plt.figure(dpi=100)
g = sns.boxplot(x = data['policy'], y = data['score'],
           showmeans = True, meanline = True, 
           order = ['F-hc-3', 'F-gnn-3', 'M-hc', 'PS', 'random', 'OPS'],
           meanprops={'color':'black'}, fliersize = 0)
g.set(xlabel = 'moderate contamination')
g.set(xticklabels=[])
plt.show()

# %%
import os
import numpy as np
import yaml 
import matplotlib.pyplot as plt
import seaborn as sns
path = '/Users/liuzhishuai/Desktop/results/SIS100-new/nn/1'
lis = os.listdir(path)
FILE = []
for i in range(len(lis)):
    FILE.append(os.path.join(path, lis[i]))

def read_data(FILE_path):
    infer_cfg = open(FILE_path)
    data = infer_cfg.read()
    yaml_reader = yaml.load(data, Loader=yaml.FullLoader)
    data_value = []
    data_score = []
    for j in range(20):
        data_value.append(yaml_reader['results'][j]['V'])
        data_score.append(yaml_reader['results'][j]['score'])
    return data_value, data_score
policy = []
Data_value = []
Data_score = []
for i in range(len(FILE)):
    if 'one_step' in FILE[i]:
        if 'learn-embedding=True' in FILE[i]:
            policy = np.hstack((policy,['M-gnn' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        elif 'raw-feature=True' in FILE[i]:
            policy = np.hstack((policy,['M-raw' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        else:
            policy = np.hstack((policy,['M-hc' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
    elif 'two_step' in FILE[i]:
        if 'learn-embedding=True' in FILE[i]:
            policy = np.hstack((policy,['F-gnn-2' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        elif 'raw-feature=True' in FILE[i]:
            policy = np.hstack((policy,['F-raw-2' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        else:
            policy = np.hstack((policy,['F-hc-2' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
    elif 'three_step' in FILE[i]:
        if 'learn-embedding=True' in FILE[i]:
            policy = np.hstack((policy,['F-gnn-3' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        elif 'raw-feature=True' in FILE[i]:
            policy = np.hstack((policy,['F-raw-3' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        else:
            policy = np.hstack((policy,['F-hc-3' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
    elif 'oracle_policy_search' in FILE[i]:
        policy = np.hstack((policy,['OPS' for i in range(20)]))
        temp1, temp2 = read_data(FILE[i])
        Data_value.append(temp1)
        Data_score.append(temp2)
    elif 'policy_search' in FILE[i]:
        policy = np.hstack((policy,['PS' for i in range(20)]))
        temp1, temp2 = read_data(FILE[i])
        Data_value.append(temp1)
        Data_score.append(temp2)
    elif 'true_probs' in FILE[i]:
        policy = np.hstack((policy,['TP' for i in range(20)]))
        temp1, temp2 = read_data(FILE[i])
        Data_value.append(temp1)
        Data_score.append(temp2)
    elif '.DS_Store' in FILE[i]:
        continue
    else:
        policy = np.hstack((policy,['random' for i in range(20)]))
        temp1, temp2 = read_data(FILE[i])
        Data_value.append(temp1)
        Data_score.append(temp2)

data = {}
data['value'] = np.hstack(Data_value)
data['score'] = np.hstack(Data_score)
data['policy'] = policy

plt.figure(dpi=100)
g = sns.boxplot(x = data['policy'], y = data['score'],
           showmeans = True, meanline = True, 
           order = ['F-hc-3', 'F-gnn-3', 'M-hc', 'PS', 'random', 'OPS'],
           meanprops={'color':'black'}, fliersize = 0)
g.set(xlabel = 'complete contamination')
g.set(xticklabels=[])
plt.show()

# %%
import os
import numpy as np
import yaml 
import matplotlib.pyplot as plt
import seaborn as sns
path = '/Users/liuzhishuai/Desktop/results/SIS100-new/contrived/0'
lis = os.listdir(path)
FILE = []
for i in range(len(lis)):
    FILE.append(os.path.join(path, lis[i]))

def read_data(FILE_path):
    infer_cfg = open(FILE_path)
    data = infer_cfg.read()
    yaml_reader = yaml.load(data, Loader=yaml.FullLoader)
    data_value = []
    data_score = []
    for j in range(20):
        data_value.append(yaml_reader['results'][j]['V'])
        data_score.append(yaml_reader['results'][j]['score'])
    return data_value, data_score
policy = []
Data_value = []
Data_score = []
for i in range(len(FILE)):
    if 'one_step' in FILE[i]:
        if 'learn-embedding=True' in FILE[i]:
            policy = np.hstack((policy,['M-gnn' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        elif 'raw-feature=True' in FILE[i]:
            policy = np.hstack((policy,['M-raw' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        else:
            policy = np.hstack((policy,['M-hc' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
    elif 'two_step' in FILE[i]:
        if 'learn-embedding=True' in FILE[i]:
            policy = np.hstack((policy,['F-gnn-2' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        elif 'raw-feature=True' in FILE[i]:
            policy = np.hstack((policy,['F-raw-2' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        else:
            policy = np.hstack((policy,['F-hc-2' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
    elif 'three_step' in FILE[i]:
        if 'learn-embedding=True' in FILE[i]:
            policy = np.hstack((policy,['F-gnn-3' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        elif 'raw-feature=True' in FILE[i]:
            policy = np.hstack((policy,['F-raw-3' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        else:
            policy = np.hstack((policy,['F-hc-3' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
    elif 'oracle_policy_search' in FILE[i]:
        policy = np.hstack((policy,['OPS' for i in range(20)]))
        temp1, temp2 = read_data(FILE[i])
        Data_value.append(temp1)
        Data_score.append(temp2)
    elif 'policy_search' in FILE[i]:
        policy = np.hstack((policy,['PS' for i in range(20)]))
        temp1, temp2 = read_data(FILE[i])
        Data_value.append(temp1)
        Data_score.append(temp2)
    elif 'true_probs' in FILE[i]:
        policy = np.hstack((policy,['TP' for i in range(20)]))
        temp1, temp2 = read_data(FILE[i])
        Data_value.append(temp1)
        Data_score.append(temp2)
    elif '.DS_Store' in FILE[i]:
        continue
    else:
        policy = np.hstack((policy,['random' for i in range(20)]))
        temp1, temp2 = read_data(FILE[i])
        Data_value.append(temp1)
        Data_score.append(temp2)

data = {}
data['value'] = np.hstack(Data_value)
data['score'] = np.hstack(Data_score)
data['policy'] = policy

plt.figure(dpi=100)
g = sns.boxplot(x = data['policy'], y = data['score'],
           showmeans = True, meanline = True, 
           order = ['F-hc-3', 'F-gnn-3', 'M-hc', 'PS', 'random', 'OPS'],
           meanprops={'color':'black'}, fliersize = 0)
g.set(xlabel = 'correct specified')
g.set(xticklabels=[])
plt.show()

# %%
import os
import numpy as np
import yaml 
import matplotlib.pyplot as plt
import seaborn as sns
path = '/Users/liuzhishuai/Desktop/results/SIS100-new/contrived/0.5'
lis = os.listdir(path)
FILE = []
for i in range(len(lis)):
    FILE.append(os.path.join(path, lis[i]))

def read_data(FILE_path):
    infer_cfg = open(FILE_path)
    data = infer_cfg.read()
    yaml_reader = yaml.load(data, Loader=yaml.FullLoader)
    data_value = []
    data_score = []
    for j in range(20):
        data_value.append(yaml_reader['results'][j]['V'])
        data_score.append(yaml_reader['results'][j]['score'])
    return data_value, data_score
policy = []
Data_value = []
Data_score = []
for i in range(len(FILE)):
    if 'one_step' in FILE[i]:
        if 'learn-embedding=True' in FILE[i]:
            policy = np.hstack((policy,['M-gnn' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        elif 'raw-feature=True' in FILE[i]:
            policy = np.hstack((policy,['M-raw' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        else:
            policy = np.hstack((policy,['M-hc' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
    elif 'two_step' in FILE[i]:
        if 'learn-embedding=True' in FILE[i]:
            policy = np.hstack((policy,['F-gnn-2' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        elif 'raw-feature=True' in FILE[i]:
            policy = np.hstack((policy,['F-raw-2' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        else:
            policy = np.hstack((policy,['F-hc-2' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
    elif 'three_step' in FILE[i]:
        if 'learn-embedding=True' in FILE[i]:
            policy = np.hstack((policy,['F-gnn-3' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        elif 'raw-feature=True' in FILE[i]:
            policy = np.hstack((policy,['F-raw-3' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        else:
            policy = np.hstack((policy,['F-hc-3' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
    elif 'oracle_policy_search' in FILE[i]:
        policy = np.hstack((policy,['OPS' for i in range(20)]))
        temp1, temp2 = read_data(FILE[i])
        Data_value.append(temp1)
        Data_score.append(temp2)
    elif 'policy_search' in FILE[i]:
        policy = np.hstack((policy,['PS' for i in range(20)]))
        temp1, temp2 = read_data(FILE[i])
        Data_value.append(temp1)
        Data_score.append(temp2)
    elif 'true_probs' in FILE[i]:
        policy = np.hstack((policy,['TP' for i in range(20)]))
        temp1, temp2 = read_data(FILE[i])
        Data_value.append(temp1)
        Data_score.append(temp2)
    elif '.DS_Store' in FILE[i]:
        continue
    else:
        policy = np.hstack((policy,['random' for i in range(20)]))
        temp1, temp2 = read_data(FILE[i])
        Data_value.append(temp1)
        Data_score.append(temp2)

data = {}
data['value'] = np.hstack(Data_value)
data['score'] = np.hstack(Data_score)
data['policy'] = policy

plt.figure(dpi=100)
g = sns.boxplot(x = data['policy'], y = data['score'],
           showmeans = True, meanline = True, 
           order = ['F-hc-3', 'F-gnn-3', 'M-hc', 'PS', 'random', 'OPS'],
           meanprops={'color':'black'}, fliersize = 0)
g.set(xlabel = 'moderate contamination')
g.set(xticklabels=[])
plt.show()

# %%
import os
import numpy as np
import yaml 
import matplotlib.pyplot as plt
import seaborn as sns
path = '/Users/liuzhishuai/Desktop/results/SIS100-new/contrived/1'
lis = os.listdir(path)
FILE = []
for i in range(len(lis)):
    FILE.append(os.path.join(path, lis[i]))

def read_data(FILE_path):
    infer_cfg = open(FILE_path)
    data = infer_cfg.read()
    yaml_reader = yaml.load(data, Loader=yaml.FullLoader)
    data_value = []
    data_score = []
    for j in range(20):
        data_value.append(yaml_reader['results'][j]['V'])
        data_score.append(yaml_reader['results'][j]['score'])
    return data_value, data_score
policy = []
Data_value = []
Data_score = []
for i in range(len(FILE)):
    if 'one_step' in FILE[i]:
        if 'learn-embedding=True' in FILE[i]:
            policy = np.hstack((policy,['M-gnn' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        elif 'raw-feature=True' in FILE[i]:
            policy = np.hstack((policy,['M-raw' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        else:
            policy = np.hstack((policy,['M-hc' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
    elif 'two_step' in FILE[i]:
        if 'learn-embedding=True' in FILE[i]:
            policy = np.hstack((policy,['F-gnn-2' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        elif 'raw-feature=True' in FILE[i]:
            policy = np.hstack((policy,['F-raw-2' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        else:
            policy = np.hstack((policy,['F-hc-2' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
    elif 'three_step' in FILE[i]:
        if 'learn-embedding=True' in FILE[i]:
            policy = np.hstack((policy,['F-gnn-3' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        elif 'raw-feature=True' in FILE[i]:
            policy = np.hstack((policy,['F-raw-3' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
        else:
            policy = np.hstack((policy,['F-hc-3' for i in range(20)]))
            temp1, temp2 = read_data(FILE[i])
            Data_value.append(temp1)
            Data_score.append(temp2)
    elif 'oracle_policy_search' in FILE[i]:
        policy = np.hstack((policy,['OPS' for i in range(20)]))
        temp1, temp2 = read_data(FILE[i])
        Data_value.append(temp1)
        Data_score.append(temp2)
    elif 'policy_search' in FILE[i]:
        policy = np.hstack((policy,['PS' for i in range(20)]))
        temp1, temp2 = read_data(FILE[i])
        Data_value.append(temp1)
        Data_score.append(temp2)
    elif 'true_probs' in FILE[i]:
        policy = np.hstack((policy,['TP' for i in range(20)]))
        temp1, temp2 = read_data(FILE[i])
        Data_value.append(temp1)
        Data_score.append(temp2)
    elif '.DS_Store' in FILE[i]:
        continue
    else:
        policy = np.hstack((policy,['random' for i in range(20)]))
        temp1, temp2 = read_data(FILE[i])
        Data_value.append(temp1)
        Data_score.append(temp2)

data = {}
data['value'] = np.hstack(Data_value)
data['score'] = np.hstack(Data_score)
data['policy'] = policy

plt.figure(dpi=100)
g = sns.boxplot(x = data['policy'], y = data['score'],
           showmeans = True, meanline = True, 
           order = ['F-hc-3', 'F-gnn-3', 'M-hc', 'PS', 'random', 'OPS'],
           meanprops={'color':'black'}, fliersize = 0)
g.set(xlabel = 'complete contamination')
g.set(xticklabels=[])
plt.show()
